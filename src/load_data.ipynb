# %%
library(affy)
library(GEOquery)
library(tidyverse)

# %%
# defining datasets
training_set   <- "GSE42568"
validation_set <- c("GSE21653", "GSE20711", "GSE88770")

curr <- training_set

# %%
# get supplementary files
getGEOSuppFiles(curr)
# Out:
#                                                             size      isdir
# c:/GitHub/kong-lab-ml-project/src/GSE42568/GSE42568_RAW.tar 980582400 FALSE
#                                                             mode
# c:/GitHub/kong-lab-ml-project/src/GSE42568/GSE42568_RAW.tar 666
#                                                             mtime
# c:/GitHub/kong-lab-ml-project/src/GSE42568/GSE42568_RAW.tar 2026-02-12 22:13:47
#                                                             ctime
# c:/GitHub/kong-lab-ml-project/src/GSE42568/GSE42568_RAW.tar 2026-02-12 22:05:43
#                                                             atime
# c:/GitHub/kong-lab-ml-project/src/GSE42568/GSE42568_RAW.tar 2026-02-12 22:13:47
#                                                             exe uname udomain
# c:/GitHub/kong-lab-ml-project/src/GSE42568/GSE42568_RAW.tar no  ramya RAMYA
#                                                             fname
# ...

# %%
# untar file
untar(paste0(curr, "/", curr, "_RAW.tar"), exdir = paste0("../data/", curr))
