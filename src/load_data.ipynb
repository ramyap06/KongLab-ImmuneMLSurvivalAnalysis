# %%
library(affy)
library(GEOquery)
library(tidyverse)

# %%
# defining datasets
training_set   <- "GSE42568"
validation_set <- c("GSE21653", "GSE20711", "GSE88770")

curr <- validation_set[3]

# %%
# get supplementary files
dir.create("../data/tar_files", recursive = TRUE, showWarnings = FALSE)
getGEOSuppFiles(curr, baseDir="../data/tar_files")
# Out:
#                                             size      isdir mode
# ../data/tar_files/GSE88770/GSE88770_RAW.tar 569784320 FALSE 666
#                                             mtime
# ../data/tar_files/GSE88770/GSE88770_RAW.tar 2026-04-02 05:07:48
#                                             ctime
# ../data/tar_files/GSE88770/GSE88770_RAW.tar 2026-04-02 05:07:28
#                                             atime               exe uname
# ../data/tar_files/GSE88770/GSE88770_RAW.tar 2026-04-02 05:07:48 no  ramya
#                                             udomain fname
# ../data/tar_files/GSE88770/GSE88770_RAW.tar RAMYA   GSE88770_RAW.tar
#                                             destdir
# ../data/tar_files/GSE88770/GSE88770_RAW.tar ../data/tar_files/GSE88770
#                                             filepath
# ../data/tar_files/GSE88770/GSE88770_RAW.tar ../data/tar_files/GSE88770/GSE88770_RAW.tar
#                                             GEO
# ...

# %%
# untar file
dir.create("../data/cel_files", recursive = TRUE, showWarnings = FALSE)
untar(paste0("../data/tar_files/", curr, "/", curr, "_RAW.tar"), exdir = paste0("../data/cel_files/", curr))
