# %%
PRE_DIR     <- "../data/preprocessed_rds_files"
DEG_DIR     <- "../data/deg_rds_files"
RESULTS_DIR <- "../results/deg"
DATA_DIR    <- "../data"

datasets        <- c("GSE42568", "GSE21653", "GSE20711", "GSE88770")
SIGNATURE_GENES <- c("TSLP", "BIRC5", "S100B", "MDK", "S100P", "RARRES3", "BLNK", "ACO1")

# %%
view_preprocessed <- function(name) {
    expr <- readRDS(file.path(PRE_DIR, paste0(name, "_expression_matrix.rds")))
    clinical <- readRDS(file.path(PRE_DIR, paste0(name, "_clinical_metadata.rds")))
}

# %%
head(view_preprocessed(datasets[1]))
# Out:
#   title                      geo_accession status
# 1 Normal breast, N1_15_12_04 GSM1045191    Public on May 26 2013
# 2 Normal breast, N4_14_12_04 GSM1045192    Public on May 26 2013
# 3 Normal breast, N5_15_12_04 GSM1045193    Public on May 26 2013
# 4 Normal breast, N6_14_12_04 GSM1045194    Public on May 26 2013
# 5 Normal breast, P1_15_12_04 GSM1045195    Public on May 26 2013
# 6 Normal breast, P10_26_1_05 GSM1045196    Public on May 26 2013
#   submission_date last_update_date type channel_count source_name_ch1
# 1 Nov 27 2012     Jul 30 2013      RNA  1             Breast tissue, normal
# 2 Nov 27 2012     Jul 30 2013      RNA  1             Breast tissue, normal
# 3 Nov 27 2012     Jul 30 2013      RNA  1             Breast tissue, normal
# 4 Nov 27 2012     Jul 30 2013      RNA  1             Breast tissue, normal
# 5 Nov 27 2012     Jul 30 2013      RNA  1             Breast tissue, normal
# 6 Nov 27 2012     Jul 30 2013      RNA  1             Breast tissue, normal
#   organism_ch1 characteristics_ch1   ⋯ er_status:ch1 grade:ch1
# 1 Homo sapiens tissue: normal breast ⋯ NA            NA
# 2 Homo sapiens tissue: normal breast ⋯ NA            NA
# 3 Homo sapiens tissue: normal breast ⋯ NA            NA
# 4 Homo sapiens tissue: normal breast ⋯ NA            NA
# 5 Homo sapiens tissue: normal breast ⋯ NA            NA
# 6 Homo sapiens tissue: normal breast ⋯ NA            NA
#   lymph node status:ch1 overall survival event:ch1
# 1 NA                    NA
# 2 NA                    NA
# 3 NA                    NA
# 4 NA                    NA
# 5 NA                    NA
# 6 NA                    NA
#   overall survival time_days:ch1 relapse free survival event:ch1
# 1 NA                             NA
# 2 NA                             NA
# 3 NA                             NA
# 4 NA                             NA
# 5 NA                             NA
# 6 NA                             NA
#   relapse free survival time_days:ch1 size:ch1 tissue:ch1    is_tumor
# 1 NA                                  NA       normal breast 0
# 2 NA                                  NA       normal breast 0
# 3 NA                                  NA       normal breast 0
# 4 NA                                  NA       normal breast 0
# 5 NA                                  NA       normal breast 0
# 6 NA                                  NA       normal breast 0
