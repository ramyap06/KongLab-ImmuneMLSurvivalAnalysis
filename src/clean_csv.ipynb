# %%
import pandas as pd
import os

# %%
expr_filename = "../datasets/csv_files/expression_matrix_test_one.csv"
clinical_filename = "../datasets/csv_files/clinical_metadata_test_one.csv"

# load datasets
expr = pd.read_csv(expr_filename)
clinical = pd.read_csv(clinical_filename)

expr.tail()
# Out:
#        sample_name gene_symbol  GSM540108  GSM540109  GSM540110  GSM540111  \
# 21650        21651      ZYG11B   6.635957   6.957342   7.299554   7.852998
# 21651        21652         ZYX   8.039407   8.101518   8.195125   9.684551
# 21652        21653       ZZEF1   6.266267   5.852577   6.125562   5.897437
# 21653        21654        ZZZ3   6.821724   6.055815   6.990111   7.499180
# 21654        21655     mir-223   4.431420   4.392363   4.064667   4.209039
#
#        GSM540112  GSM540113  GSM540114  GSM540115  ...  GSM540364  GSM540365  \
# 21650   7.861657   8.174834   7.816731   8.500056  ...   7.069218   6.933989
# 21651   8.696353  10.332553   9.150694   9.874273  ...   9.773243  10.421647
# 21652   5.889624   6.433840   5.927160   5.873355  ...   6.269974   6.291125
# 21653   7.680644   6.908704   7.267744   7.553148  ...   7.488613   7.293796
# 21654   3.751116   4.178111   4.591735   5.908435  ...   5.077201   5.369013
#
# ...

# %%
# rename column for clarity
expr_filtered = expr.iloc[:, 1:]
# clinical_filtered = clinical.drop(columns=['sample_id'])
# clinical_filtered.rename(columns={'Unnamed: 0': 'sample_name'}, inplace=True)
# expr_filtered = expr.rename(columns={'Unnamed: 0': 'sample_name'})

# %%
expr_filtered.head()
# Out:
#   gene_symbol  GSM540108  GSM540109  GSM540110  GSM540111  GSM540112  \
# 0        A1BG   6.146570   5.632868   7.407916   5.717083   5.667256
# 1    A1BG-AS1   5.192952   6.270687   5.594629   4.476920   5.047257
# 2        A1CF   4.136334   4.220885   4.546149   3.887450   3.876345
# 3         A2M   7.202705   6.328396   8.172368   8.021876   7.659437
# 4     A2M-AS1   5.378281   4.429702   6.103873   5.039355   4.568131
#
#    GSM540113  GSM540114  GSM540115  GSM540116  ...  GSM540364  GSM540365  \
# 0   5.821602   5.582540   5.678218   6.570997  ...   5.768699   5.915461
# 1   5.420414   4.874277   4.710615   5.320223  ...   4.654715   4.821310
# 2   3.737222   3.619344   3.747788   3.939471  ...   3.730873   3.814982
# 3   8.497944   8.218462   8.664218   8.092863  ...   8.240868   8.781016
# 4   5.923578   5.995361   6.468561   4.866476  ...   6.963635   5.482779
#
#    GSM540366  GSM540367  GSM540368  GSM540369  GSM540370  GSM540371  \
# ...

# %%
clinical_filtered.head()
# Out:
#   sample_name  is_tumor  patient_age  tumor_grade  t_stage  er_status  \
# 0   GSM540108         1         67.0          2.0      2.0        1.0
# 1   GSM540109         1         47.0          3.0      NaN        0.0
# 2   GSM540110         1         41.0          3.0      NaN        1.0
# 3   GSM540111         1         62.0          3.0      1.0        0.0
# 4   GSM540112         1         60.0          2.0      2.0        1.0
#
#    lymph_node_status  relapse_free_event  relapse_free_time
# 0                1.0                 1.0              731.0
# 1                1.0                 1.0                NaN
# 2                1.0                 1.0                NaN
# 3                1.0                 1.0             1770.0
# 4                1.0                 1.0              871.0

# %%
# save datasets
expr_filtered.to_csv(expr_filename, index=False)
clinical_filtered.to_csv(clinical_filename, index=False)
