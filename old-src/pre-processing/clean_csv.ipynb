# %%
import pandas as pd

# %%
expr_filename = "../datasets/csv_files/expression_matrix_train.csv"
clinical_filename = "../datasets/csv_files/clinical_metadata_train.csv"

# load datasets
expr = pd.read_csv(expr_filename)
clinical = pd.read_csv(clinical_filename)

clinical.head()
# Out:
#   sample_name  is_tumor  patient_age  tumor_grade  tumor_size  er_status  \
# 0  GSM1045191         0          NaN          NaN         NaN        NaN
# 1  GSM1045192         0          NaN          NaN         NaN        NaN
# 2  GSM1045193         0          NaN          NaN         NaN        NaN
# 3  GSM1045194         0          NaN          NaN         NaN        NaN
# 4  GSM1045195         0          NaN          NaN         NaN        NaN
#
#    lymph_node_status  relapse_free_event  relapse_free_time
# 0                NaN                 NaN                NaN
# 1                NaN                 NaN                NaN
# 2                NaN                 NaN                NaN
# 3                NaN                 NaN                NaN
# 4                NaN                 NaN                NaN

# %%
expr.head()
# Out:
#   gene_symbol  GSM1045191  GSM1045192  GSM1045193  GSM1045194  GSM1045195  \
# 0        A1BG    5.061765    5.384287    5.462018    5.104647    4.940101
# 1    A1BG-AS1    4.213439    4.497735    5.442854    4.142935    3.836375
# 2        A1CF    2.960794    3.844863    3.603847    3.710878    2.919968
# 3         A2M    6.814863    6.845371    4.532851    7.000975    7.117619
# 4     A2M-AS1    4.973031    4.252506    3.920574    4.064233    5.378826
#
#    GSM1045196  GSM1045197  GSM1045198  GSM1045199  ...  GSM1045302  \
# 0    5.087535    5.647719    5.502169    4.935021  ...    5.612234
# 1    3.840813    4.108047    4.117811    4.374573  ...    5.274847
# 2    3.246907    2.954523    3.181512    3.115969  ...    3.695726
# 3    6.683618    6.839982    7.182724    6.365128  ...    5.206523
# 4    5.553602    5.198546    5.391066    5.675315  ...    3.974318
#
#    GSM1045303  GSM1045304  GSM1045305  GSM1045306  GSM1045307  GSM1045308  \
# ...

# %%
# rename column for clarity
expr_filtered = expr.iloc[:, 1:]
clinical_filtered = clinical.drop(columns=['sample_id'])
clinical_filtered.rename(columns={'Unnamed: 0': 'sample_name'}, inplace=True)
# expr_filtered = expr.rename(columns={'Unnamed: 0': 'sample_name'})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 3
#       1 # rename column for clarity
#       2 expr_filtered = expr.iloc[:, 1:]
# ----> 3 clinical_filtered = clinical.drop(columns=['sample_id'])
#       4 clinical_filtered.rename(columns={'Unnamed: 0': 'sample_name'}, inplace=True)
#       5 # expr_filtered = expr.rename(columns={'Unnamed: 0': 'sample_name'})
#
# File c:\GitHub\KongLab-ImmuneMLSurvivalAnalysis\.venv\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
# ...

# %%
expr_filtered.head()
# Out:
#   gene_symbol  GSM1045191  GSM1045192  GSM1045193  GSM1045194  GSM1045195  \
# 0        A1BG    5.061765    5.384287    5.462018    5.104647    4.940101
# 1    A1BG-AS1    4.213439    4.497735    5.442854    4.142935    3.836375
# 2        A1CF    2.960794    3.844863    3.603847    3.710878    2.919968
# 3         A2M    6.814863    6.845371    4.532851    7.000975    7.117619
# 4     A2M-AS1    4.973031    4.252506    3.920574    4.064233    5.378826
#
#    GSM1045196  GSM1045197  GSM1045198  GSM1045199  ...  GSM1045302  \
# 0    5.087535    5.647719    5.502169    4.935021  ...    5.612234
# 1    3.840813    4.108047    4.117811    4.374573  ...    5.274847
# 2    3.246907    2.954523    3.181512    3.115969  ...    3.695726
# 3    6.683618    6.839982    7.182724    6.365128  ...    5.206523
# 4    5.553602    5.198546    5.391066    5.675315  ...    3.974318
#
#    GSM1045303  GSM1045304  GSM1045305  GSM1045306  GSM1045307  GSM1045308  \
# ...

# %%
clinical_filtered.head()
# Out:
#   sample_name  is_tumor  patient_age  tumor_grade  tumor_size  er_status  \
# 0  GSM1045191         0          NaN          NaN         NaN        NaN
# 1  GSM1045192         0          NaN          NaN         NaN        NaN
# 2  GSM1045193         0          NaN          NaN         NaN        NaN
# 3  GSM1045194         0          NaN          NaN         NaN        NaN
# 4  GSM1045195         0          NaN          NaN         NaN        NaN
#
#    lymph_node_status  relapse_free_event  relapse_free_time
# 0                NaN                 NaN                NaN
# 1                NaN                 NaN                NaN
# 2                NaN                 NaN                NaN
# 3                NaN                 NaN                NaN
# 4                NaN                 NaN                NaN

# %%
# save datasets
expr_filtered.to_csv(expr_filename, index=False)
clinical_filtered.to_csv(clinical_filename, index=False)
